# %%
import numpy as np
import matplotlib.pyplot as plt

samples = np.load('../data/iq_samples/fm_station101o9.npy')

plt.figure(figsize=(12,4))
plt.magnitude_spectrum(samples, Fs=2.4e9)
plt.title("FM Broadcast Spectrum")
plt.show()
